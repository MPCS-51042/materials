# %% [markdown]
# [Images from Here](https://realpython.com/python-concurrency/)
#
# IO Bound
#
# Waiting at the airport or the train station
#
# ![Screen%20Shot%202021-02-15%20at%2012.25.09%20PM.png](attachment:Screen%20Shot%202021-02-15%20at%2012.25.09%20PM.png)

# %% [markdown]
# CPU Bound
#
# Phone Banking off of a CSV with a bunch of phone numbers in it
#
# ![Screen%20Shot%202021-02-15%20at%2012.24.50%20PM.png](attachment:Screen%20Shot%202021-02-15%20at%2012.24.50%20PM.png)
